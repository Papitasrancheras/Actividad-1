# %%
# Se importan las librerías pandas y numpy 
import pandas as pd
import numpy as np

# %%
# Cargo mi archivo Exportaciones.csv
df = pd.read_csv("Exportaciones.csv")
#df.info()
df
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 2      alb  1997         energy       12.8071       3.0441  195.5730
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %% [markdown]
# # Aplicacion de filtros

# %%
# Filtro 1: Por objeto 
f1=df[df["iso3"] == "alb"] # Variables cualitativas u objetos
f1
#f2
f2=f1[f1["h_insurance"] > 0.5] # Variables cuantitativas 
f2

# %%
# Filtro 2: Por objeto y cuantitativa
#Todas la exportaciones de sector Gmatrix:insurance con "gprocfoods" mayor a 7
f3=df[df["sector_GMatrix"] == "insurance"] # Variables cualitativas u objetos
f3
#"gprocfoods" mayor a 7
f4=f3[f3["g_procfoods"] > 7]
f4

# %%
#Filtro 3: 
# Todas las exportaciones de year 1997 a 2005 
f5=df[(df["year"] >= 1997) & (df["year"] <= 2005)]
f5
#f5
#(df["year"][5:10]) # imprime de la linea 5 a la 10
#(df[df.year, 1997:2005])
#x = df[["year"]]
#exp= df.iloc[1997:2005,: ]
#exp
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0     alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1     alb  1997      otherprim        0.0521       5.7779    0.0979
# 2     alb  1997         energy       12.8071       3.0441  195.5730
# 3     alb  1997      procfoods        0.8223       0.0041    0.0706
# 4     alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...   ...   ...            ...           ...          ...       ...
# 6880  zwe  2004        finance       12.9971       0.2822    0.2540
# 6881  zwe  2004      insurance        2.3389       0.0342    0.0250
# 6882  zwe  2004         obsict       14.5142       0.3718    0.3170
# 6883  zwe  2004      oconsumer        2.3766       0.0570    0.0672
# 6884  zwe  2004      oservices        9.4795       0.9173    0.5526
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 0         25.0267        0.3817      0.1455      0.9488  ...     0.0019
# ...

# %%
#Filtro 4
# Todas las exportaciones con "Vxsharefwd" mayor a 0.5 y con "Vxsharebwd" menor a 0.5
f6=df[df["VXsharefwd"] > 0.5]
f7=df[df["VXsharebwd"] < 0.5]
d1=df[(df["VXsharefwd"] > 0.5) & (df["VXsharebwd"] < 0.5)]
d1

# %%
#Filtro 5
e1 = df[df["iso3"] == "kor"] |(df)["iso3"] == "tha"

# %%
#Filtro 6 
# Las 15 exportaciones de "ye ar: 2004, con "ho services" mayor a 10 
h1=df[(df["year"] == 2004) & (df["h_oservices"] > 10)]
h1

# %%
#Filtro 7 
#Todas las exportaciones que no sean de "sectorGmatrix:machinery"
filtro9=df[~(df["sector_GMatrix"] == "machinery")]
filtro9
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 2      alb  1997         energy       12.8071       3.0441  195.5730
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Filtro 8 
#Todas las exportaciones que no sean de "Dxshare mayor a 0.5"
filtro10=df[~(df["DXshare"] == 0.5)]
filtro10

# %%
# Filtro 9
# Todas las exportaciones que sean de "h_oconsumer" igual a 0.02 o h_obscit mayor que 10
filtro11=df[(df["h_oconsumer"] == 0.02) | (df["h_obsict"] > 10)]
filtro11
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 51     arg  1997         obsict      172.1130       1.8889   125.9700
# 56     aus  1997         energy      264.1910     327.3620  8225.6200
# 63     aus  1997       paperpub       79.4958      42.9939    27.4799
# 71     aus  1997          water       65.8972      26.7741    29.4982
# 73     aus  1997   distribution      560.1380     330.4000   166.1190
# ...    ...   ...            ...           ...          ...        ...
# 13175  zmb  2011      oservices        0.9600       2.9100     9.7900
# 13187  zwe  2011      nonmetmin        0.4400       0.7200     0.2000
# 13198  zwe  2011        finance       15.7700       0.3200     0.2900
# 13200  zwe  2011         obsict       18.5100       0.4300     0.3700
# 13202  zwe  2011      oservices       12.1400       1.0900     0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...
